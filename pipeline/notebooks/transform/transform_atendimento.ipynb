# %%
import sys
import pandas as pd
from pathlib import Path

# Caminho real do notebook 
NOTEBOOK_DIR = Path.cwd() 

# Sobe até a raiz do projeto (shopnow/) 
ROOT = NOTEBOOK_DIR.parents[2] 

# Adiciona ao sys.path 
if str(ROOT) not in sys.path: sys.path.append(str(ROOT))
from pipeline.extract import carregar_dados_csv

# %%
df_atendimento = carregar_dados_csv()["atendimento"]
df_atendimento
# Out:
# → Carregando: atendimento_raw.csv
# → Carregando: clientes_raw.csv
# → Carregando: compras_raw.csv
# → Carregando: estoque_raw.csv
# → Carregando: financeiro_raw.csv
# → Carregando: fornecedores_raw.csv
# → Carregando: logistica_raw.csv
# → Carregando: marketing_campanhas_raw.csv
# → Carregando: marketing_performance_raw.csv
# → Carregando: produtos_raw.csv
# → Carregando: rh_raw.csv
# → Carregando: vendas_raw.csv
#       id_ticket  id_pedido     canal  categoria               data_abertura  \
# 0             1  PED-24592      Chat    Entrega  2026-01-13 07:39:43.656347
# 1             2  PED-23434      Chat  Pagamento  2025-08-18 22:57:14.315558
# 2             3  PED-40495      Chat      troca  2025-05-03 04:24:07.905906
# 3             4  PED-87236     Email      Troca  2025-06-28 06:19:05.006886
# 4             5  PED-46421      chat      troca  2025-06-12 19:38:28.214701
# ...         ...        ...       ...        ...                         ...
# 4495       4496  PED-51887      Chat  Pagamento  2025-08-16 19:30:18.983041
# 4496       4497  PED-99760     Email      troca  2025-06-26 05:19:58.045837
# 4497       4498  PED-49473  Telefone    Entrega  2025-05-28 17:54:29.264572
# 4498       4499  PED-48365  Telefone  Pagamento  2025-05-15 19:17:17.224039
# 4499       4500  PED-97573      Chat    Entrega  2025-10-08 21:53:28.409261
#
#                  data_fechamento  satisfacao  custo_atendimento
# 0     2026-01-16 14:39:43.656347           2              17.28
# 1     2025-08-22 18:57:14.315558           1               6.64
# 2     2025-05-04 05:24:07.905906           5              28.07
# 3     2025-06-30 13:19:05.006886           2              43.40
# 4     2025-06-14 12:38:28.214701           3              10.62
# ...                          ...         ...                ...
# 4495  2025-08-17 22:30:18.983041           5              47.77
# 4496  2025-06-27 11:19:58.045837           1              12.20
# 4497  2025-05-29 05:54:29.264572           1              15.23
# 4498  2025-05-16 18:17:17.224039           5              59.12
# 4499  2025-10-12 11:53:28.409261           3              58.49
#
# [4500 rows x 8 columns]
